# %%
# %matplotlib inline
from __future__ import division
import matplotlib.pyplot as plt
import numpy as np
fig,ax=plt.subplots()
x=np.linspace(10,0,1000,endpoint=False)#(0,10]にするため０と１０を入れ替えて終点を含まなくする 
plt.ylim(ymin=0)#グラフに表示するｙの下限
plt.ylim(ymax=200)#ｙの上限
for i in range(50):
    y=4*x**9/(i+1)**2+(i+1) #短期総費用関数の一例
    ax.plot(x,y,'y',linewidth=0.5,alpha=0.8)
plt.show()
plt.savefig("STC.jpg")#グラフ画像をPDFとして保存

# %%
# %matplotlib inline
from __future__ import division
import matplotlib.pyplot as plt
import numpy as np
fig,ax=plt.subplots()
x=np.linspace(10,0,1000,endpoint=False)
plt.ylim(ymin=0)
plt.ylim(ymax=200)
for i in range(20):
    y=4*x**8/(i+1)**2+(i+1)/x #短期平均費用曲線
    ax.plot(x,y,'c',linewidth=0.5,alpha=0.8)
plt.show()
plt.savefig("SAC.jpg")
# x=L**a*K**b　生産関数　L=労働投入量　K=資本投入量
#短期費用曲線　wL+rK w=賃金率　r=レンタル率
#短期平均費用曲線　y=w*L/x+r*K/x
